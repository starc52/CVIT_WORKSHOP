# %%
base_url = "https://gist.githubusercontent.com/alti-tude/710cb9d4dfc7ebcd0afb9cf93d8f6a8d/raw/574730ba009e69b81d6c79f2fef2c3dd5145db0a/"

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
df = pd.read_csv(base_url+"purchases.csv", index_col=0)

df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
df = pd.read_json(base_url+"purchases.json")

df
# Out:
#         apples  oranges
# David        1        2
# June         3        0
# Lily         0        7
# Robert       2        3

# %%
df = pd.read_csv(base_url+'IMDB-Movie-Data.csv',index_col='Title')

df.tail()
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %% [markdown]
# ### Task

# %%
music_df = pd.read_csv(base_url+'MusicTop50.csv', index_col=0)
music_df
# Out:
#                                            Track.Name       Artist.Name  \
# 1                                            Se�orita      Shawn Mendes
# 2                                               China          Anuel AA
# 3                       boyfriend (with Social House)     Ariana Grande
# 4                     Beautiful People (feat. Khalid)        Ed Sheeran
# 5                         Goodbyes (Feat. Young Thug)       Post Malone
# 6                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 7                                              Ransom         Lil Tecca
# 8                                   How Do You Sleep?         Sam Smith
# 9                               Old Town Road - Remix         Lil Nas X
# 10                                            bad guy     Billie Eilish
# 11                                           Callaita         Bad Bunny
# 12              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 13 columns):
# Track.Name            50 non-null object
# Artist.Name           50 non-null object
# Genre                 50 non-null object
# Beats.Per.Minute      48 non-null float64
# Energy                49 non-null float64
# Danceability..db..    50 non-null int64
# Loudness..            50 non-null int64
# Liveness.             48 non-null float64
# Valence ()            49 non-null float64
# Length                47 non-null float64
# Acousticness          50 non-null int64
# Speechiness           50 non-null int64
# Popularity            49 non-null float64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 5.5+ KB

# %%
music_df.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 1                         Se�orita   Shawn Mendes    canadian pop
# 2                            China       Anuel AA  reggaeton flow
# 3    boyfriend (with Social House)  Ariana Grande       dance pop
# 4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability..db..  Loudness..  Liveness.  \
# 1             117.0    55.0                  76          -6        8.0
# 2             105.0    81.0                  79          -4        8.0
# 3             190.0    80.0                  40          -4       16.0
# 4              93.0    65.0                  64          -8        8.0
# 5               NaN    65.0                  58          -4       11.0
#
#    Valence ()  Length  Acousticness  Speechiness  Popularity
# 1        75.0   191.0             4            3        79.0
# ...

# %%
music_df.tail()
# Out:
#                                        Track.Name       Artist.Name    Genre  \
# 46                                One Thing Right        Marshmello  brostep
# 47                                      Te Robar�         Nicky Jam    latin
# 48                                        Happier        Marshmello  brostep
# 49                                  Call You Mine  The Chainsmokers      edm
# 50  Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran      pop
#
#     Beats.Per.Minute  Energy  Danceability..db..  Loudness..  Liveness.  \
# 46              88.0    62.0                  66          -2        NaN
# 47             176.0    75.0                  67          -4        8.0
# 48             100.0    79.0                  69          -3       17.0
# 49             104.0    70.0                  59          -6       41.0
# 50              95.0    79.0                  75          -6        7.0
#
#     Valence ()  Length  Acousticness  Speechiness  Popularity
# ...

# %%
music_df.rename(columns = {"Track.Name":"trackname", "Artist.Name":"artist", "Genre":"genre", "Beats.Per.Minute":"bpm", "Energy":"energy", "Danceability..db..":"db", "Loudness..":"loudness", "Liveness.":"liveness", "Valence ()":"valence", "Length":"length", "Acousticness":"acousticness", "Speechiness":"speechiness", "Popularity":"popularity"}, inplace=True)

music_df
# Out:
#                                             trackname            artist  \
# 1                                            Se�orita      Shawn Mendes
# 2                                               China          Anuel AA
# 3                       boyfriend (with Social House)     Ariana Grande
# 4                     Beautiful People (feat. Khalid)        Ed Sheeran
# 5                         Goodbyes (Feat. Young Thug)       Post Malone
# 6                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 7                                              Ransom         Lil Tecca
# 8                                   How Do You Sleep?         Sam Smith
# 9                               Old Town Road - Remix         Lil Nas X
# 10                                            bad guy     Billie Eilish
# 11                                           Callaita         Bad Bunny
# 12              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 13 columns):
# trackname       50 non-null object
# artist          50 non-null object
# genre           50 non-null object
# bpm             48 non-null float64
# energy          49 non-null float64
# db              50 non-null int64
# loudness        50 non-null int64
# liveness        48 non-null float64
# valence         49 non-null float64
# length          47 non-null float64
# acousticness    50 non-null int64
# speechiness     50 non-null int64
# popularity      49 non-null float64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 5.5+ KB

# %% [markdown]
# ### Cleaning Task

# %%
music_df['valence'].dropna()
# Out:
# 1     75.0
# 2     61.0
# 3     70.0
# 4     55.0
# 5     18.0
# 6     84.0
# 8     35.0
# 9     64.0
# 10    56.0
# 11    24.0
# 12    38.0
# 13    45.0
# 14    76.0
# 15    10.0
# 16    14.0
# 17    43.0
# 18    91.0
# 19    50.0
# 20    41.0
# 21    63.0
# 22    48.0
# 23    58.0
# 24    80.0
# 25    68.0
# 26    87.0
# 27    54.0
# 28    40.0
# 29    66.0
# 30    94.0
# 31    36.0
# 32    33.0
# 33    68.0
# 34    18.0
# 35    39.0
# 36    32.0
# 37    62.0
# 38    91.0
# 39    95.0
# 40    68.0
# 41    40.0
# 42    73.0
# 43    32.0
# 44    35.0
# 45    75.0
# 46    44.0
# 47    80.0
# 48    67.0
# 49    50.0
# 50    61.0
# Name: valence, dtype: float64

# %%
mbpm=music_df['bpm']
mean_mbpm = mbpm.mean()
print(mean_mbpm)
print()
mbpm.fillna(mean_mbpm)
# Out:
# 119.35416666666667
# 1     117.000000
# 2     105.000000
# 3     190.000000
# 4      93.000000
# 5     119.354167
# 6     102.000000
# 7     180.000000
# 8     111.000000
# 9     136.000000
# 10    135.000000
# 11    176.000000
# 12     96.000000
# 13    110.000000
# 14    176.000000
# 15    101.000000
# 16     93.000000
# 17    176.000000
# 18     90.000000
# 19    130.000000
# 20    158.000000
# 21    124.000000
# 22    154.000000
# 23     92.000000
# 24     92.000000
# 25    135.000000
# 26    119.354167
# 27     98.000000
# 28     96.000000
# 29     94.000000
# 30     93.000000
# 31     85.000000
# 32    140.000000
# 33     96.000000
# 34     98.000000
# 35    100.000000
# 36    114.000000
# 37    176.000000
# 38    152.000000
# 39    138.000000
# 40     95.000000
# 41    104.000000
# 42     85.000000
# 43     96.000000
# 44    136.000000
# 45     98.000000
# 46     88.000000
# 47    176.000000
# 48    100.000000
# 49    104.000000
# 50     95.000000
# Name: bpm, dtype: float64

# %%
mlive=music_df['liveness']
median_mlive = mlive.median()
print(median_mlive)
print()
mbpm.fillna(median_mlive)
# Out:
# 11.0
# 1     117.0
# 2     105.0
# 3     190.0
# 4      93.0
# 5      11.0
# 6     102.0
# 7     180.0
# 8     111.0
# 9     136.0
# 10    135.0
# 11    176.0
# 12     96.0
# 13    110.0
# 14    176.0
# 15    101.0
# 16     93.0
# 17    176.0
# 18     90.0
# 19    130.0
# 20    158.0
# 21    124.0
# 22    154.0
# 23     92.0
# 24     92.0
# 25    135.0
# 26     11.0
# 27     98.0
# 28     96.0
# 29     94.0
# 30     93.0
# 31     85.0
# 32    140.0
# 33     96.0
# 34     98.0
# 35    100.0
# 36    114.0
# 37    176.0
# 38    152.0
# 39    138.0
# 40     95.0
# 41    104.0
# 42     85.0
# 43     96.0
# 44    136.0
# 45     98.0
# 46     88.0
# 47    176.0
# 48    100.0
# 49    104.0
# 50     95.0
# Name: bpm, dtype: float64

# %%
music_df.fillna(df.median(), inplace=True)

# %% [markdown]
# ### Query Task

# %%
artistname=music_df[music_df['popularity']==music_df['popularity'].min()]['artist']
AllArtistSongs=music_df[music_df['artist']=='Shawn Mendes']
AllArtistSongs[AllArtistSongs['loudness']==AllArtistSongs['loudness'].max()]
# Out:
#               trackname        artist         genre  bpm  energy  db  \
# 26  If I Can't Have You  Shawn Mendes  canadian pop  NaN    82.0  69
#
#     loudness  liveness  valence  length  acousticness  speechiness  popularity
# 26        -4       NaN     87.0   191.0            49            6        70.0
